# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
plt.style.use('ggplot')
from sympy import *
from matplotlib import cm
# %matplotlib inline

# %%
from life_model import Life_model

# %% [markdown]
# Запустим симуляцию с хорошими параметрами и построим зависимость числа жертв/хищников от времени

# %%
# %%time
lm = Life_model(p_pred_move=0.7, t_hungry=20, p_pred_exist=0.01, p_wall_exist=0.2, 
                p_vict_exist=0.5, t_rep_vict=10, t_rep_pred=40, n=20, m=40, random_state=1)
t = 5000
vict = np.zeros(t)
pred = np.zeros(t)
for step in range(t):
    lm.next()
    vict[step] = lm.alive[0]
    pred[step] = lm.alive[1]
# Out:
# CPU times: user 12.9 s, sys: 69.9 ms, total: 13 s
# Wall time: 13.1 s

# %%
plt.figure(figsize=(20,5))
plt.plot(np.arange(t),vict,'green',label='victims')
plt.plot(np.arange(t),pred,'red',label='predators')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Как видно гипотеза о переодичности популяций выполняется.
#
# Для наглядности отнормируем данные:

# %%
plt.figure(figsize=(20,5))
plt.plot(np.arange(t//2),((vict - np.mean(vict)) / np.std(vict))[:t//2],'green',label='victims')
plt.plot(np.arange(t//2),((pred - np.mean(pred))/ np.std(pred))[:t//2],'red',label='predators')
plt.legend(loc='best')
plt.show()
plt.figure(figsize=(20,5))
plt.plot(np.arange(t//2,t),((vict - np.mean(vict)) / np.std(vict))[t//2:t],'green',label='victims')
plt.plot(np.arange(t//2,t),((pred - np.mean(pred))/ np.std(pred))[t//2:t],'red',label='predators')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# У хищников также стабильно видны минипериоды на фоне главного тренда. Скорее всего это связано с геометрией поля.

# %% [markdown]
# Для запуска из консоли с визуализацией:

# %% [markdown]
# python3 life_model.py visualize=1 p_pred_move=0.7 t_hungry=20 p_pred_exist=0.01 p_wall_exist=0.2 p_vict_exist=0.5 t_rep_vict=10 t_rep_pred=40 n=20 m=40 random_state=1
